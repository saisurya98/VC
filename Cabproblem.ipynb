# %%
import pandas as pd
p1=pd.read_csv("Cab_Data.csv")
p2=pd.read_csv("City.csv")
p3=pd.read_csv("Customer_ID.csv")
p4=pd.read_csv("Transaction_ID.csv")

# %%
p1.tail()
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 359387          4.80          69.24       63.3600
# 359388          8.40         113.75      106.8480
# 359389         27.75         437.07      349.6500
# 359390          8.80         146.19      114.0480
# 359391         12.76         191.58      177.6192

# %%
p1['StandarddateinYY-MM-DD']=p1['Date of Travel'].apply(lambda x: pd.to_datetime('1900-01-01') + pd.to_timedelta(x, unit='D'))

# %%
p1.tail()
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip StandarddateinYY-MM-DD
# 359387          4.80          69.24       63.3600             2018-01-10
# 359388          8.40         113.75      106.8480             2018-01-06
# 359389         27.75         437.07      349.6500             2018-01-07
# 359390          8.80         146.19      114.0480             2018-01-07
# 359391         12.76         191.58      177.6192             2018-01-04

# %%
p1 = p1.drop('Date of Travel', axis=1)

# %%
p1.tail()
# Out:
#         Transaction ID     Company           City  KM Travelled  \
# 359387        10440101  Yellow Cab  WASHINGTON DC          4.80
# 359388        10440104  Yellow Cab  WASHINGTON DC          8.40
# 359389        10440105  Yellow Cab  WASHINGTON DC         27.75
# 359390        10440106  Yellow Cab  WASHINGTON DC          8.80
# 359391        10440107  Yellow Cab  WASHINGTON DC         12.76
#
#         Price Charged  Cost of Trip StandarddateinYY-MM-DD
# 359387          69.24       63.3600             2018-01-10
# 359388         113.75      106.8480             2018-01-06
# 359389         437.07      349.6500             2018-01-07
# 359390         146.19      114.0480             2018-01-07
# 359391         191.58      177.6192             2018-01-04

# %%
p2.head()
# Out:
#              City Population    Users
# 0     NEW YORK NY  8,405,837  302,149
# 1      CHICAGO IL  1,955,130  164,468
# 2  LOS ANGELES CA  1,595,037  144,132
# 3        MIAMI FL  1,339,155   17,675
# 4  SILICON VALLEY  1,177,609   27,247

# %%
p3.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
p4.tail()
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card

# %%
p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Transaction ID          359392 non-null  int64
#  1   Company                 359392 non-null  object
#  2   City                    359392 non-null  object
#  3   KM Travelled            359392 non-null  float64
#  4   Price Charged           359392 non-null  float64
#  5   Cost of Trip            359392 non-null  float64
#  6   StandarddateinYY-MM-DD  359392 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 19.2+ MB

# %%
p3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
p4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
a1 = p4['Transaction ID']
a2=p1['Transaction ID']
a=0

set_a2 = set(a2)
for i in a1:
    if i in set_a2:
        a += 1

print(f"Number of matching Transaction IDs: {a}")

b1=p4['Customer ID']
b2=p3['Customer ID']

b=0

set_b2 = set(b2)
for i in b1:
    if i in set_b2:
        b += 1

print(f"Number of matching Customer IDs: {b}")
# Out:
# Number of matching Transaction IDs: 359392
# Number of matching Customer IDs: 440098

# %%
for i, id1 in enumerate(a1):
    if i == 0:
        print("First value in a1:", id1)
    if id1 in a2:
        a = a + 1
    if i == len(a1) - 1:
        print("Last value in a1:", id1)
# Out:
# First value in a1: 10000011
# Last value in a1: 10440108

# %%
p4_new=p4[:359392 ]
p4_new.tail()
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 359387        10359398        52022         Cash
# 359388        10359399        52234         Cash
# 359389        10359400        52326         Card
# 359390        10359401        51413         Card
# 359391        10359402        51697         Cash

# %%
merged_df = pd.merge(p1, p4, on='Transaction ID', how='inner')
merged_df
# Out:
#         Transaction ID     Company           City  KM Travelled  \
# 0             10000011    Pink Cab     ATLANTA GA         30.45
# 1             10000012    Pink Cab     ATLANTA GA         28.62
# 2             10000013    Pink Cab     ATLANTA GA          9.04
# 3             10000014    Pink Cab     ATLANTA GA         33.17
# 4             10000015    Pink Cab     ATLANTA GA          8.73
# ...                ...         ...            ...           ...
# 359387        10440101  Yellow Cab  WASHINGTON DC          4.80
# 359388        10440104  Yellow Cab  WASHINGTON DC          8.40
# 359389        10440105  Yellow Cab  WASHINGTON DC         27.75
# 359390        10440106  Yellow Cab  WASHINGTON DC          8.80
# 359391        10440107  Yellow Cab  WASHINGTON DC         12.76
#
#         Price Charged  Cost of Trip StandarddateinYY-MM-DD  Customer ID  \
# 0              370.95      313.6350             2016-01-10        29290
# ...

# %%
new_merged_df=pd.merge(merged_df,p3,on='Customer ID',how='inner')
new_merged_df
# Out:
#         Transaction ID     Company            City  KM Travelled  \
# 0             10000011    Pink Cab      ATLANTA GA         30.45
# 1             10351127  Yellow Cab      ATLANTA GA         26.19
# 2             10412921  Yellow Cab      ATLANTA GA         42.55
# 3             10000012    Pink Cab      ATLANTA GA         28.62
# 4             10320494  Yellow Cab      ATLANTA GA         36.38
# ...                ...         ...             ...           ...
# 359387        10439790  Yellow Cab      SEATTLE WA         16.66
# 359388        10439799  Yellow Cab  SILICON VALLEY         13.72
# 359389        10439838  Yellow Cab       TUCSON AZ         19.00
# 359390        10439840  Yellow Cab       TUCSON AZ          5.60
# 359391        10439846  Yellow Cab       TUCSON AZ         13.30
#
#         Price Charged  Cost of Trip StandarddateinYY-MM-DD  Customer ID  \
# 0              370.95      313.6350             2016-01-10        29290
# ...

# %%
new_merged_df = new_merged_df.drop_duplicates()
new_merged_df = new_merged_df.dropna()

# %%
new_merged_df['City'].unique()
# Out:
# array(['ATLANTA GA', 'AUSTIN TX', 'BOSTON MA', 'CHICAGO IL', 'DALLAS TX',
#        'DENVER CO', 'LOS ANGELES CA', 'MIAMI FL', 'NASHVILLE TN',
#        'NEW YORK NY', 'ORANGE COUNTY', 'PHOENIX AZ', 'PITTSBURGH PA',
#        'SACRAMENTO CA', 'SAN DIEGO CA', 'SEATTLE WA', 'SILICON VALLEY',
#        'TUCSON AZ', 'WASHINGTON DC'], dtype=object)

# %%
import matplotlib.pyplot as plt
Yellow_cab_customercount_peryear = [746382.8056, 379255.7352, 1506717.572, 3068590.9256, 1104003.1532, 357000.0696, 3285976.5808, 596000.0532, 85247.6844, 26451080.7712, 355006.0412, 157344.488, 68058.2188, 62002.18, 949273.7016, 491903.5184, 976454.7428, 80971.1204, 3299103.8087999998]

Pink_cab_customercount_peryear = [96050.076, 147445.29, 262001.698, 318722.488, 24730.112, 40584.939, 1125732.065, 162301.191, 64284.534, 1511474.388, 101995.833, 35596.394, 17107.738, 55324.012, 637889.769, 112781.335, 340250.531, 59289.575, 193766.353]

index = ['ATLANTA GA', 'AUSTIN TX', 'BOSTON MA', 'CHICAGO IL', 'DALLAS TX',
       'DENVER CO', 'LOS ANGELES CA', 'MIAMI FL', 'NASHVILLE TN',
       'NEW YORK NY', 'ORANGE COUNTY', 'PHOENIX AZ', 'PITTSBURGH PA',
       'SACRAMENTO CA', 'SAN DIEGO CA', 'SEATTLE WA', 'SILICON VALLEY',
       'TUCSON AZ', 'WASHINGTON DC']
df = pd.DataFrame({'Yellow Cab': Yellow_cab_customercount_peryear, 'Pink Cab': Pink_cab_customercount_peryear}, index=index)

plt.figure(figsize=(12, 6))
colors = ['yellow', 'lightcoral']

ax = df.plot(kind='bar', color=colors, width=0.8)
ax.set_xlabel('City', fontsize=12)
ax.set_ylabel('profit', fontsize=12)
ax.set_title('profit by City for Yellow Cab and Pink Cab', fontsize=14)

# Customize the legend
ax.legend(['Yellow Cab', 'Pink Cab'], fontsize=10)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)
# plt.tight_layout()
plt.subplots_adjust(bottom=0.3)
plt.show()

# %%
new_merged_df['profit']=new_merged_df['Price Charged']-new_merged_df['Cost of Trip']
new_merged_df
a1=new_merged_df[new_merged_df['Company']=='Pink Cab']
a2=new_merged_df[new_merged_df['Company']=='Yellow Cab']

print('aggregate profit of pink cab is',a1['profit'].sum())
print('aggregate profit of yellow cab is',a2['profit'].sum())
print('number of rides given by pink cab company is',len(a1))
print('number of rides given by yellow cab company is',len(a2))

print('profit per ride for pink cab company is',a1['profit'].sum()/len(a1))
print('profit per ride for yellow cab company is',a2['profit'].sum()/len(a2))
# Out:
# aggregate profit of pink cab is 5307328.3209999995
# aggregate profit of yellow cab is 44020373.17079999
# number of rides given by pink cab company is 84711
# number of rides given by yellow cab company is 274681
# profit per ride for pink cab company is 62.65217410961976
# profit per ride for yellow cab company is 160.2599858410301

# %%
profit_by_city_pink = a1.groupby('City')['profit'].sum()
profit_by_city_yellow = a2.groupby('City')['profit'].sum()
print(len(profit_by_city_pink),len(profit_by_city_yellow))
# Out:
# 19 19

# %%
new_merged_df_2k16 = new_merged_df[new_merged_df['StandarddateinYY-MM-DD'].dt.year == 2016]
Cust_pink = new_merged_df_2k16[new_merged_df_2k16['Company']=='Pink Cab']
# Cust_pink['profitperkm']=Cust_pink['profit']/Cust_pink['KM Travelled']
# print(' avg profit per km in 2k16  pink company is', Cust_pink['profitperkm'].sum())
print('profit made in  2016 by pink company is', Cust_pink['profit'].sum())
Yellow_pink = new_merged_df_2k16[new_merged_df_2k16['Company']=='Yellow Cab']
sumprofit_2k16_pink=Cust_pink['profit'].sum()
totalrev2k16=Cust_pink['Cost of Trip'].sum()
print((sumprofit_2k16_pink/totalrev2k16))
profit_2k16_yellow=Yellow_pink['profit'].sum()
totalrev_Yellow_2k16=Yellow_pink['Cost of Trip'].sum()
# print((profit_2k16_yellow/totalrev_Yellow_2k16))
print('profit made in  2016 by yellow company is', Yellow_pink['profit'].sum())


cut_pink_monthjan16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 1]
cut_pink_monthfeb16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 2]
cut_pink_monthmar16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 3]
cut_pink_monthapr16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 4]
cut_pink_monthmay16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 5]
cut_pink_monthjune16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 6]
cut_pink_monthjuly16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 7]
cut_pink_monthaug16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 8]
cut_pink_monthsep16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 9]
cut_pink_monthoct16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 10]
cut_pink_monthnnov16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 11]
cut_pink_monthdec16 =Cust_pink[Cust_pink['StandarddateinYY-MM-DD'].dt.month== 12]

cut_yellow_monthjan16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 1]
cut_yellow_monthfeb16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 2]
cut_yellow_monthmar16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 3]
cut_yellow_monthapr16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 4]
cut_yellow_monthmay16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 5]
cut_yellow_monthjune16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 6]
cut_yellow_monthjuly16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 7]
cut_yellow_monthaug16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 8]
cut_yellow_monthsep16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 9]
cut_yellow_monthoct16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 10]
cut_yellow_monthnnov16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 11]
cut_yellow_monthdec16 =Yellow_pink[Yellow_pink['StandarddateinYY-MM-DD'].dt.month== 12]
num_rows_pink_16= len(Cust_pink)
num_rows_yellow_16=len(Yellow_pink)
# print(num_rows_pink_16,num_rows_yellow_16)
# Out:
# profit made in  2016 by pink company is 1686457.5130000003
# 0.2751032369581896
# profit made in  2016 by yellow company is 13786935.9512

# %%
new_merged_df_2k17 = new_merged_df[new_merged_df['StandarddateinYY-MM-DD'].dt.year == 2017]
Cust_pink_17 = new_merged_df_2k17[new_merged_df_2k17['Company']=='Pink Cab']
Yellow_pink_17 = new_merged_df_2k17[new_merged_df_2k17['Company']=='Yellow Cab']

cut_pink_monthjan17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 1]
cut_pink_monthfeb17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 2]
cut_pink_monthmar17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 3]
cut_pink_monthapr17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 4]
cut_pink_monthmay17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 5]
cut_pink_monthjune17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 6]
cut_pink_monthjuly17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 7]
cut_pink_monthaug17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 8]
cut_pink_monthsep17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 9]
cut_pink_monthoct17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 10]
cut_pink_monthnnov17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 11]
cut_pink_monthdec17 =Cust_pink_17[Cust_pink_17['StandarddateinYY-MM-DD'].dt.month== 12]

cut_yellow_monthjan17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 1]
cut_yellow_monthfeb17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 2]
cut_yellow_monthmar17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 3]
cut_yellow_monthapr17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 4]
cut_yellow_monthmay17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 5]
cut_yellow_monthjune17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 6]
cut_yellow_monthjuly17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 7]
cut_yellow_monthaug17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 8]
cut_yellow_monthsep17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 9]
cut_yellow_monthoct17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 10]
cut_yellow_monthnnov17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 11]
cut_yellow_monthdec17 =Yellow_pink_17[Yellow_pink_17['StandarddateinYY-MM-DD'].dt.month== 12]
num_rows_pink_17= len(Cust_pink)
num_rows_yellow_17=len(Yellow_pink)
# print(num_rows_pink_17,num_rows_yellow_17)
# new_merged_df_2k17
print('profit made in  2017 by pink company is', Cust_pink_17['profit'].sum())
print('profit made in  2017 by yellow company is', Yellow_pink_17['profit'].sum())
# Out:
# profit made in  2017 by pink company is 2033435.1339999998
# profit made in  2017 by yellow company is 16586614.0632

# %%
new_merged_df_2k18 = new_merged_df[new_merged_df['StandarddateinYY-MM-DD'].dt.year == 2018]
Cust_pink_18 = new_merged_df_2k18[new_merged_df_2k18['Company']=='Pink Cab']
Yellow_pink_18 = new_merged_df_2k18[new_merged_df_2k18['Company']=='Yellow Cab']

cut_pink_monthjan18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 1]
cut_pink_monthfeb18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 2]
cut_pink_monthmar18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 3]
cut_pink_monthapr18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 4]
cut_pink_monthmay18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 5]
cut_pink_monthjune18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 6]
cut_pink_monthjuly18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 7]
cut_pink_monthaug18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 8]
cut_pink_monthsep18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 9]
cut_pink_monthoct18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 10]
cut_pink_monthnnov18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 11]
cut_pink_monthdec18 =Cust_pink_18[Cust_pink_18['StandarddateinYY-MM-DD'].dt.month== 12]

cut_yellow_monthjan18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 1]
cut_yellow_monthfeb18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 2]
cut_yellow_monthmar18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 3]
cut_yellow_monthapr18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 4]
cut_yellow_monthmay18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 5]
cut_yellow_monthjune18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 6]
cut_yellow_monthjuly18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 7]
cut_yellow_monthaug18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 8]
cut_yellow_monthsep18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 9]
cut_yellow_monthoct18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 10]
cut_yellow_monthnnov18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 11]
cut_yellow_monthdec18 =Yellow_pink_18[Yellow_pink_18['StandarddateinYY-MM-DD'].dt.month== 12]
num_rows_pink_18= len(Cust_pink)
num_rows_yellow_18=len(Yellow_pink)
# print(num_rows_pink_18,num_rows_yellow_18)

print('profit made in  2018 by pink company is', Cust_pink_18['profit'].sum())
print('profit made in  2018 by yellow company is', Yellow_pink_18['profit'].sum())
new_merged_df_2k18
# Out:
# profit made in  2018 by pink company is 1578972.4620000003
# profit made in  2018 by yellow company is 13609461.478
#         Transaction ID     Company            City  KM Travelled  \
# 1             10351127  Yellow Cab      ATLANTA GA         26.19
# 2             10412921  Yellow Cab      ATLANTA GA         42.55
# 4             10320494  Yellow Cab      ATLANTA GA         36.38
# 5             10324737  Yellow Cab      ATLANTA GA          6.18
# 6             10395626    Pink Cab      ATLANTA GA         13.39
# ...                ...         ...             ...           ...
# 359387        10439790  Yellow Cab      SEATTLE WA         16.66
# 359388        10439799  Yellow Cab  SILICON VALLEY         13.72
# 359389        10439838  Yellow Cab       TUCSON AZ         19.00
# 359390        10439840  Yellow Cab       TUCSON AZ          5.60
# 359391        10439846  Yellow Cab       TUCSON AZ         13.30
#
# ...

# %% [markdown]
# BAR GRAPH FOR customer count per year

# %%
import matplotlib.pyplot as plt
Yellow_cab_customercount_peryear = [num_rows_yellow_16,num_rows_yellow_17,num_rows_yellow_18]
Pink_cab_customercount_peryear = [num_rows_pink_16,num_rows_pink_17,num_rows_pink_18]
index = ['2016', '2017', '2018']
df = pd.DataFrame({'yellow cab customers per year': Yellow_cab_customercount_peryear,
                   'pink cab customers per year': Pink_cab_customercount_peryear}, index=index)
ax = df.plot.bar(rot=0)

# %% [markdown]
# line graph to observe trend in profit by year

# %%
Yellow_cab_totalprofit_peryear = [Yellow_pink['profit'].sum(), Yellow_pink_17['profit'].sum(), Yellow_pink_18['profit'].sum()]
Pink_cab_totalprofit_peryear = [Cust_pink['profit'].sum(), Cust_pink_17['profit'].sum(), Cust_pink_18['profit'].sum()]
index = ['2016', '2017', '2018']

# Create a DataFrame
data = pd.DataFrame({
    'Yellow Cab Total Profit': Yellow_cab_totalprofit_peryear,
    'Pink Cab Total Profit': Pink_cab_totalprofit_peryear,
    'Year': index
})

# Create a figure and axes
plt.figure(figsize=(12, 6))
ax = plt.gca()

# Plot the data as line charts
ax.plot(data['Year'], data['Yellow Cab Total Profit'], label='Yellow Cab', marker='o')
ax.plot(data['Year'], data['Pink Cab Total Profit'], label='Pink Cab', marker='o')

# Annotate the data points on the lines
for i, row in data.iterrows():
    ax.annotate(f'{row["Yellow Cab Total Profit"]:.0f}', (row['Year'], row['Yellow Cab Total Profit']), textcoords="offset points", xytext=(0, 5), ha='center')
    ax.annotate(f'{row["Pink Cab Total Profit"]:.0f}', (row['Year'], row['Pink Cab Total Profit']), textcoords="offset points", xytext=(0, 5), ha='center')

# Add labels and titles
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Profit', fontsize=12)
plt.title('Profit Over Years for Yellow Cab and Pink Cab', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
data = {'Yellow_cab_customercount_bymonth': [len(cut_yellow_monthjan16), len(cut_yellow_monthfeb16), len(cut_yellow_monthmar16), len(cut_yellow_monthapr16), len(cut_yellow_monthmay16),len(cut_yellow_monthjune16),
                                           len(cut_yellow_monthjuly16),len(cut_yellow_monthaug16),len(cut_yellow_monthsep16),len(cut_yellow_monthoct16),len(cut_yellow_monthnnov16),len(cut_yellow_monthdec16)],
        'pink_cab_customercount_bymonth': [len(cut_pink_monthjan16), len(cut_pink_monthfeb16), len(cut_pink_monthmar16), len(cut_pink_monthapr16), len(cut_pink_monthmay16),len(cut_pink_monthjune16),
                                           len(cut_pink_monthjuly16),len(cut_pink_monthaug16),len(cut_pink_monthsep16),len(cut_pink_monthoct16),len(cut_pink_monthnnov16),len(cut_pink_monthdec16)],
         'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June','july', 'aug', 'sep','oct','nov', 'dec'] }

# Create a DataFrame
df = pd.DataFrame(data)

# Plot a line graph
df.plot(x='Month', y=['Yellow_cab_customercount_bymonth','pink_cab_customercount_bymonth'], kind='line', title='Customer count for two cab companies in 2016 based on each month')

# Add labels and titles
plt.xlabel('month')
plt.ylabel('Count')
plt.legend(['Yellow_cab_customercount_bymonth','pink_cab_customercount_bymonth'])
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# customer count vs date line graph to both companies

# %%
line_data={ 'Date': pd.date_range(start='2016-01-01', periods=36, freq='MS'),

          'Yellow_cab_customercount': [len(cut_yellow_monthjan16), len(cut_yellow_monthfeb16), len(cut_yellow_monthmar16), len(cut_yellow_monthapr16), len(cut_yellow_monthmay16),len(cut_yellow_monthjune16),
                                           len(cut_yellow_monthjuly16),len(cut_yellow_monthaug16),len(cut_yellow_monthsep16),len(cut_yellow_monthoct16),len(cut_yellow_monthnnov16),len(cut_yellow_monthdec16),

                                               len(cut_yellow_monthjan17), len(cut_yellow_monthfeb17), len(cut_yellow_monthmar17), len(cut_yellow_monthapr17), len(cut_yellow_monthmay17),len(cut_yellow_monthjune17),
                                           len(cut_yellow_monthjuly17),len(cut_yellow_monthaug17),len(cut_yellow_monthsep17),len(cut_yellow_monthoct17),len(cut_yellow_monthnnov17),len(cut_yellow_monthdec17),

                                               len(cut_yellow_monthjan18), len(cut_yellow_monthfeb18), len(cut_yellow_monthmar18), len(cut_yellow_monthapr18), len(cut_yellow_monthmay18),len(cut_yellow_monthjune18),
                                           len(cut_yellow_monthjuly18),len(cut_yellow_monthaug18),len(cut_yellow_monthsep18),len(cut_yellow_monthoct18),len(cut_yellow_monthnnov18),len(cut_yellow_monthdec18)],


        'pink_cab_customercount': [len(cut_pink_monthjan16), len(cut_pink_monthfeb16), len(cut_pink_monthmar16), len(cut_pink_monthapr16), len(cut_pink_monthmay16),len(cut_pink_monthjune16),
                                           len(cut_pink_monthjuly16),len(cut_pink_monthaug16),len(cut_pink_monthsep16),len(cut_pink_monthoct16),len(cut_pink_monthnnov16),len(cut_pink_monthdec16),

                                           len(cut_pink_monthjan17), len(cut_pink_monthfeb17), len(cut_pink_monthmar17), len(cut_pink_monthapr17), len(cut_pink_monthmay17),len(cut_pink_monthjune17),
                                           len(cut_pink_monthjuly17),len(cut_pink_monthaug17),len(cut_pink_monthsep17),len(cut_pink_monthoct17),len(cut_pink_monthnnov17),len(cut_pink_monthdec17),

                                           len(cut_pink_monthjan18), len(cut_pink_monthfeb18), len(cut_pink_monthmar18), len(cut_pink_monthapr18), len(cut_pink_monthmay18),len(cut_pink_monthjune18),
                                           len(cut_pink_monthjuly18),len(cut_pink_monthaug18),len(cut_pink_monthsep18),len(cut_pink_monthoct18),len(cut_pink_monthnnov18),len(cut_pink_monthdec18)]  }


# Create a DataFrame
linedata = pd.DataFrame(line_data)

# Set the 'Date' column as the index for better plotting
linedata.set_index('Date', inplace=True)

# Plot a two-line graph
plt.figure(figsize=(20, 6))

ax = linedata.plot(kind='line', title='number of customers who used yellow and pink cabs from 2016-01-01 to 2018-12-31')
# Add labels and titles
plt.xlabel('Month and Year')
plt.ylabel('number of customers ')
plt.legend(["Yellow_cab_customercount ", "pink_cab_customercount B"])
plt.grid(True)

# Show the plot
plt.show()
